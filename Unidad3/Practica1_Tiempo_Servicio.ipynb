# %% [markdown]
# <a href="https://colab.research.google.com/github/DystopiaScript/Simulacion/blob/main/Unidad3/Practica1_Tiempo_Servicio.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##**Simulación**
# ##**Unidad 3**
# ###Variables Aleatorias
# ###Facilitador: José Gabriel Rodríguez Rivas
# ###Practica 1: Simular los tiempos de servicio en un restaurante de comida rápida
#
# ####**Alumno: Jasher Abraham Carrazco Vaquera**
# ####**Número de Control: C23041201**
# ####**Fecha: 20/3/2025**

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats

# Parámetros de la distribución lognormal
mu = 1.0   # Media de la variable logarítmica
sigma = 0.5  # Desviación estándar de la variable logarítmica
n = 100  # Número de variables aleatorias a generar

# Generar n números aleatorios U ~ Uniform(0, 1)
U = np.random.uniform(0, 1, n)

# Transformada inversa para generar tiempos de inactividad lognormales
Z = mu + sigma * stats.norm.ppf(U)
T = np.exp(Z)  # Tiempos generados

# Mostrar los resultados
print("Tiempos de inactividad generados:", T)

# Graficar histograma de los tiempos de inactividad generados
plt.hist(T, bins=20, edgecolor='black', density=True)

# Graficar la función teórica de densidad de la distribución lognormal
x = np.linspace(min(T), max(T), 100)
pdf = stats.lognorm.pdf(x, sigma, scale=np.exp(mu))
plt.plot(x, pdf, 'r', label='Distribución lognormal teórica')

plt.title("Histograma de los tiempos de inactividad (Distribución Lognormal)")
plt.xlabel("Tiempo de inactividad")
plt.ylabel("Densidad de probabilidad")
plt.legend()
plt.show()
# Out:
# Tiempos de inactividad generados: [2.67616732 2.4956292  2.15190751 2.94173134 1.93375722 2.02758835
#  3.68571818 5.97296624 2.16675121 3.74678237 3.43989554 4.74353085
#  5.01015738 4.38141646 2.22762148 1.47698249 5.50703135 1.88714741
#  1.4291185  1.86901367 1.04514355 3.57584331 3.49475548 4.35569802
#  2.62532891 1.79401713 3.98749693 1.49143209 2.53610477 2.82497429
#  3.10964518 3.33866847 2.01435272 1.11853661 2.1627966  4.42748604
#  3.43423691 1.09292711 5.92567511 1.37553156 2.62272262 1.24538268
#  2.25242815 5.15066591 1.38278128 3.70488441 2.56319847 2.57879387
#  2.21259686 2.22898128 3.60617818 3.19956688 2.28656546 1.32982678
#  4.54872882 2.19977565 2.26206605 3.65729186 6.7812341  1.81727758
#  1.11434468 1.58800194 4.86296116 2.126392   2.10004962 3.71141451
#  2.35313684 1.00318473 1.72255808 3.1343257  3.78118547 2.49409197
#  2.9232385  2.24180879 2.26726708 2.32794956 2.17254437 1.9050287
#  2.00143222 5.4497995  5.46879999 3.35123499 2.24963066 3.27116556
# ...

# %% [markdown]
# # Conclusiones de la Práctica de Simulación de Tiempos de Servicio
#
# - **Aplicación del Método de la Transformada Inversa:**
#   La práctica demuestra cómo se utiliza el método de la transformada inversa para transformar números aleatorios uniformes en tiempos de servicio que siguen una distribución exponencial. Esto valida la aplicabilidad del método para modelar procesos de servicio en escenarios reales.
#
# - **Adecuación del Modelo Exponencial:**
#   En el contexto del restaurante de comida rápida, la distribución exponencial se ajusta adecuadamente para representar el tiempo entre eventos (servicios). La práctica evidencia que, al emplear un parámetro de tasa (λ) apropiado, se pueden simular tiempos de servicio que reflejan tanto la frecuencia común como la posibilidad de tiempos excepcionalmente altos debido a la naturaleza de la distribución.
#
# - **Visualización y Análisis de Resultados:**
#   Los histogramas generados en la práctica permiten observar la dispersión y la asimetría típica de una distribución exponencial. La presencia de algunos tiempos de servicio significativamente mayores confirma la "cola" larga de la distribución, lo que es característico en procesos con variabilidad alta.
#
# - **Influencia del Parámetro de Tasa:**
#   Se aprecia que ajustar el valor de λ tiene un impacto directo en los tiempos de servicio simulados. Por ejemplo, con λ = 1/2 se obtienen tiempos generalmente menores en comparación con λ = 1/3, donde se evidencian tiempos de servicio más prolongados y mayor dispersión, lo que resalta la importancia de calibrar correctamente este parámetro en simulaciones reales.
#
# - **Implementación Práctica en Python:**
#   La práctica muestra de manera concreta cómo implementar y ejecutar un modelo de simulación en Python. Esto no solo refuerza la comprensión teórica, sino que también aporta una herramienta práctica para el análisis y la optimización de procesos en entornos de atención al cliente.
