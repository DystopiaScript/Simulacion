# %% [markdown]
# <a href="https://colab.research.google.com/github/DystopiaScript/Simulacion/blob/main/Unidad3/Practica2_Tiempos_Inactividad.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##**Simulación**
# ##**Unidad 3**
# ###Variables Aleatorias
# ###Facilitador: José Gabriel Rodríguez Rivas
# ###Practica 2: Simular tiempos de inactividad de un brazo de robot de soldadura en una fábrica de vehículos
# ####**Alumno: Jasher Abraham Carrazco Vaquera**
# ####**Número de Control: C23041201**
# ####**Fecha: 3/21/2025**

# %%
import numpy as np
import matplotlib.pyplot as plt

#Parárametro de la distribución exponencial (tasa de servicio)
lamda_servicio=1/2 #Tiempo promedio de servicio = 2 min

#Funcion para generar un tiempo de servicio
def generar_tiempo_servicio(lamda_servicio):
  u = np.random.uniform(0,1) #Generar numero aletario uniforme
  tiempo_servicio = -1/lamda_servicio * np.log(1-u) #Aplicar transformada inversa
  return tiempo_servicio

# Generar 100 tiempos de servicio
tiempos_servicio = [generar_tiempo_servicio(lamda_servicio) for _ in range(100)]

# %%
# Mostrar los tiempos de servicio
print("Tiempos de servicio generados:", tiempos_servicio)
# Graficar los tiempos de servicio simulados
plt.hist(tiempos_servicio, bins=10, edgecolor='black', alpha=0.7)
plt.title('Distribución de Tiempos de Servicio Simulados (Exponencial)')
plt.xlabel('Tiempo de servicio (minutos)')
plt.ylabel('Frecuencia')
plt.show()
# Out:
# Tiempos de servicio generados: [np.float64(0.6233294037955408), np.float64(2.6177955174277416), np.float64(3.3019183137214174), np.float64(3.532047144667366), np.float64(2.0659896176804855), np.float64(7.812587860116423), np.float64(2.0829187267654627), np.float64(2.993018049154364), np.float64(0.40714854171350806), np.float64(2.2878354163696657), np.float64(0.05690213062381061), np.float64(2.741814134100803), np.float64(1.2584879563284759), np.float64(0.04197255816101769), np.float64(2.3989080710960544), np.float64(0.30618606599465825), np.float64(1.276066345103659), np.float64(0.9488671195454582), np.float64(3.7553506316388945), np.float64(0.3026638784374015), np.float64(0.5176386033861576), np.float64(0.10085335115838169), np.float64(1.8559001608163184), np.float64(1.7568027926042493), np.float64(5.175801816427427), np.float64(0.3000703220529507), np.float64(3.224858648325587), np.float64(0.16655053561172564), np.float64(0.7499940931707124), np.float64(0.014999236435390143), np.fl
# ...

# %% [markdown]
# # Conclusiones de la Práctica: Simulación de Tiempos de Inactividad del Brazo de Robot
#
# - **Aplicación del Método de la Transformada Inversa:**
#   La práctica demuestra cómo se puede aplicar la transformada inversa para transformar números aleatorios uniformes en tiempos de inactividad que siguen una distribución exponencial, modelando así de manera precisa la aleatoriedad en el comportamiento del sistema.
#
# - **Modelado Adecuado con la Distribución Exponencial:**
#   La elección de la distribución exponencial es adecuada para simular los tiempos entre inicios de inactividad (por fallos o mantenimiento) en un brazo de robot. Al usar un parámetro de tasa (λ) igual a 1/10, se refleja un tiempo promedio de inactividad de 10 minutos, capturando la probabilidad de eventos con tiempos muy variables.
#
# - **Validación a través de Visualización:**
#   La representación gráfica mediante histogramas permite observar la dispersión y la característica "cola larga" típica de la distribución exponencial, lo que valida el modelo teórico y su adecuación para describir los tiempos de inactividad.
#
# - **Implicaciones para la Gestión Industrial:**
#   Comprender la variabilidad en los tiempos de inactividad es fundamental para planificar mantenimientos y optimizar la producción en fábricas. La simulación ayuda a identificar patrones de fallo y a desarrollar estrategias para minimizar el impacto de las interrupciones en la línea de producción.
#
# - **Implementación Práctica en Python:**
#   La práctica ilustra cómo implementar este modelo de simulación utilizando Python, lo que no solo refuerza los conceptos teóricos de variables aleatorias y transformada inversa, sino que también ofrece una herramienta práctica para el análisis y la toma de decisiones en entornos industriales.
