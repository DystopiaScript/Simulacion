# %% [markdown]
# <a href="https://colab.research.google.com/github/DystopiaScript/Simulacion/blob/main/Unidad3/Practica3_Tiempos_Servicio_Inactividad.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##**Simulación**
# ##**Unidad 3**
# ###Variables Aleatorias
# ###Facilitador: José Gabriel Rodríguez Rivas
# ###Practica 3: Simular los tiempos de servicio o inactividad en una fábrica de chips.
#
# ####**Alumno: Jasher Abraham Carrazco Vaquera**
# ####**Número de Control: C23041201**
# ####**Fecha: 26/3/2025**

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats

# Parámetros de la distribución lognormal
mu = 1.0   # Media de la variable logarítmica
sigma = 0.5  # Desviación estándar de la variable logarítmica
n = 100  # Número de variables aleatorias a generar

# Generar n números aleatorios U ~ Uniform(0, 1)
U = np.random.uniform(0, 1, n)

# Transformada inversa para generar tiempos de inactividad lognormales
Z = mu + sigma * stats.norm.ppf(U)
T = np.exp(Z)  # Tiempos generados

# Mostrar los resultados
print("Tiempos de inactividad generados:", T)

# Graficar histograma de los tiempos de inactividad generados
plt.hist(T, bins=20, edgecolor='black', density=True)

# Graficar la función teórica de densidad de la distribución lognormal
x = np.linspace(min(T), max(T), 100)
pdf = stats.lognorm.pdf(x, sigma, scale=np.exp(mu))
plt.plot(x, pdf, 'r', label='Distribución lognormal teórica')

plt.title("Histograma de los tiempos de inactividad (Distribución Lognormal)")
plt.xlabel("Tiempo de inactividad")
plt.ylabel("Densidad de probabilidad")
plt.legend()
plt.show()
# Out:
# Tiempos de inactividad generados: [ 1.56357456  2.64644971  2.49051547  1.45203934  0.60640364  1.51061167
#   1.38294318  5.18314833  3.36392492  4.43399025  3.90932081  6.36128137
#   1.87846421  2.11309386  2.18125859  1.85439074  2.4645922   1.65901028
#   6.55925123  1.93243711  2.93465903  3.23991991  2.33822018  0.88979983
#   2.24698966  4.59728618  3.70734239  2.75063879  2.12785403  2.63351962
#   2.8208415   3.62120396  7.15528469  0.92742406  2.44392711  3.88914023
#   4.71405673  0.77868881  3.44373967  1.440772   13.06367864  1.13997493
#   4.15897673  5.65838058  3.18532471  2.72523295  1.87204069  0.92443541
#   1.76740641  3.05223569  2.83968479  2.791771    4.79270146  5.48742522
#   1.57939423  2.25911807  3.23896733  1.39370324  5.17179675  2.63143587
#   1.41492415  1.42524757  2.41625542  4.89690315  3.07061302  1.89600414
#   3.6707172   1.90392531  2.01700328  2.08551399  2.7249696   5.99782424
# ...

# %% [markdown]
# # Conclusiones de la Práctica: Simulación de Tiempos de Servicio/Inactividad en una Fábrica de Chips
#
# - **Aplicación del Método de la Transformada Inversa con Distribución Lognormal:**
#   La práctica ilustra cómo transformar números aleatorios uniformes en tiempos que siguen una distribución lognormal, aprovechando que el logaritmo de los tiempos se distribuye normalmente.
#
# - **Adecuación del Modelo Lognormal para Fenómenos Industriales:**
#   La distribución lognormal es idónea para modelar tiempos de servicio o inactividad en una fábrica de chips, ya que permite capturar la alta asimetría y la presencia de valores extremos, donde la mayoría de los eventos son de corta duración pero algunos pueden ser considerablemente más largos.
#
# - **Implementación Práctica y Validación en Python:**
#   Se evidencia la facilidad de implementar este modelo en Python usando bibliotecas como NumPy, Matplotlib y SciPy, lo que facilita la generación de datos simulados y la visualización mediante histogramas, permitiendo comparar los resultados empíricos con la función teórica de la distribución lognormal.
#
# - **Implicaciones para la Optimización y Gestión de Procesos:**
#   La simulación de los tiempos de inactividad o servicio en una línea de producción automatizada brinda una herramienta valiosa para la planificación del mantenimiento preventivo, la detección de cuellos de botella y la mejora de la eficiencia operativa en la fabricación de chips.
#
# - **Profundización en el Análisis de Variabilidad:**
#   El enfoque lognormal permite entender mejor la variabilidad inherente a los procesos industriales, facilitando la identificación de patrones de inactividad que pueden derivar en estrategias de optimización y toma de decisiones basadas en datos.
