# %% [markdown]
# <a href="https://colab.research.google.com/github/DystopiaScript/Simulacion/blob/main/Unidad3/Practica4_Demanda_Diaria.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##**Simulación**
# ##**Unidad 3**
# ###Variables Aleatorias
# ###Facilitador: José Gabriel Rodríguez Rivas
# ###Practica 4: Simular la demanda diaria de clientes en una tienda de telefono móviles.
#
# ####**Alumno: Jasher Abraham Carrazco Vaquera**
# ####**Número de Control: C23041201**
# ####**Fecha: 26/20/2025**

# %%
import numpy as np
import matplotlib.pyplot as plt
# Parámetro de la distribución Poisson (media de la demanda diaria)
lambda_poisson = 5  # Por ejemplo, 5 teléfonos móviles por día

# Generar una variable aleatoria uniforme U ~ Uniform(0, 1)
n = 100  # Número de simulaciones
U = np.random.uniform(0, 1, n)

# Aplicar la transformada inversa para la distribución Poisson
def poisson_inverse_transform(lambda_poisson, U):
    k = 0
    F_k = np.exp(-lambda_poisson)  # Primera probabilidad acumulada (k=0)
    while U > F_k:
        k += 1
        F_k += (lambda_poisson**k * np.exp(-lambda_poisson)) / math.factorial(k)
    return k

# Generar demanda simulada usando transformada inversa
demanda_simulada = [poisson_inverse_transform(lambda_poisson, u) for u in U]

# Mostrar los resultados
print("Demanda diaria simulada:", demanda_simulada)

# Graficar histograma de la demanda simulada
plt.hist(demanda_simulada, bins=np.arange(0, max(demanda_simulada) + 1) - 0.5, edgecolor='black', density=True)
plt.title("Simulación de demanda diaria (Distribución Poisson)")
plt.xlabel("Número de productos demandados")
plt.ylabel("Frecuencia")
plt.show()
# Out:
# Demanda diaria simulada: [6, 3, 6, 9, 4, 2, 4, 4, 6, 5, 7, 5, 3, 8, 3, 5, 6, 7, 5, 3, 9, 5, 6, 2, 4, 11, 5, 3, 4, 7, 5, 3, 4, 5, 5, 8, 8, 6, 5, 5, 2, 12, 8, 2, 0, 7, 6, 3, 3, 13, 2, 4, 5, 6, 4, 3, 7, 6, 7, 6, 7, 8, 4, 4, 8, 2, 7, 3, 5, 9, 4, 7, 3, 11, 1, 6, 7, 8, 3, 7, 4, 5, 9, 8, 3, 6, 6, 5, 6, 9, 5, 7, 3, 6, 3, 2, 5, 2, 1, 7]

# %% [markdown]
# # Conclusiones de la Práctica: Simulación de Demanda Diaria en una Tienda de Teléfonos Móviles
#
# - **Aplicación del Método de la Transformada Inversa para Distribución Poisson:**
#   La práctica demuestra el uso del método de la transformada inversa para generar variables aleatorias que siguen una distribución Poisson, lo cual es idóneo para modelar la demanda discreta diaria de clientes.
#
# - **Justificación del Modelo Poisson:**
#   La distribución Poisson es apropiada para simular la demanda diaria ya que:
#   - Los eventos (ventas de teléfonos) se cuentan en números enteros.
#   - Se asume una tasa promedio constante de demanda, basada en datos históricos.
#   - Cada día se considera un evento independiente, lo que coincide con las propiedades de la distribución Poisson.
#
# - **Optimización de la Gestión de Inventarios:**
#   Simular la demanda diaria permite prever la cantidad de productos que se venderán en un periodo determinado. Esto es fundamental para ajustar el stock, minimizando costos de almacenamiento y evitando pérdidas por falta de inventario.
#
# - **Implementación y Visualización en Python:**
#   La práctica ilustra cómo implementar la simulación en Python mediante la generación de números aleatorios y la aplicación de la transformada inversa. El uso de histogramas para visualizar la distribución de la demanda simulada permite validar el modelo y ajustar parámetros según las necesidades reales del negocio.
#
# - **Soporte para Toma de Decisiones Estratégicas:**
#   Al conocer la distribución y variabilidad de la demanda, los gestores pueden planificar promociones, campañas de reposición y estrategias de precios, asegurando una respuesta óptima a las variaciones en la demanda del mercado.
