# %% [markdown]
# <a href="https://colab.research.google.com/github/DystopiaScript/Simulacion/blob/main/Unidad3/Practica5_Demanda_Diaria.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##**Simulación**
# ##**Unidad 3**
# ###Variables Aleatorias
# ###Facilitador: José Gabriel Rodríguez Rivas
# ###Practica 5: Simular La demanda diaria de productos tecnológicos
#
# ####**Alumno: Jasher Abraham Carrazco Vaquera**
# ####**Número de Control: C23041201**
# ####**Fecha: 26/20/2025**

# %%
import numpy as np
import matplotlib.pyplot as plt
from math import comb

# Parámetros de la distribución binomial
n = 10   # Número de visitantes diarios
p = 0.30 # Probabilidad de que un visitante realice una compra

# Generar un número aleatorio uniforme U ~ Uniform(0, 1)
num_simulaciones = 100  # Número de simulaciones (días)
U = np.random.uniform(0, 1, num_simulaciones)

# Función de distribución acumulada de la distribución binomial
def binomial_pmf(n, k, p):
    return comb(n, k) * (p**k) * ((1 - p)**(n - k))

def binomial_inverse_transform(n, p, U):
    F_k = 0  # Inicializamos la FDA
    k = 0
    while True:
        F_k += binomial_pmf(n, k, p)  # Sumamos la probabilidad hasta que F(k) >= U
        if U <= F_k:
            return k  # Este valor de k es el número de clientes que hicieron una compra
        k += 1

# Generar la cantidad de clientes que realizaron una compra en cada simulación (día)
compras_simuladas = [binomial_inverse_transform(n, p, u) for u in U]

# Mostrar resultados
print("Número de clientes que realizaron una compra en cada simulación (día):")
print(compras_simuladas)

# Graficar los resultados
plt.hist(compras_simuladas, bins=np.arange(min(compras_simuladas), max(compras_simuladas) + 1) - 0.5, edgecolor='black')
plt.title("Simulación de número de compras diarias (Distribución Binomial)")
plt.xlabel("Número de compras")
plt.ylabel("Frecuencia")
plt.show()
# Out:
# Número de clientes que realizaron una compra en cada simulación (día):
# [0, 3, 6, 1, 5, 1, 5, 1, 3, 2, 2, 7, 3, 4, 3, 2, 3, 3, 4, 4, 1, 2, 3, 1, 3, 4, 3, 5, 3, 4, 3, 3, 4, 2, 3, 3, 1, 3, 3, 3, 2, 5, 1, 3, 2, 1, 5, 1, 2, 1, 5, 2, 4, 6, 6, 1, 2, 2, 2, 3, 0, 3, 3, 3, 4, 3, 3, 1, 2, 3, 2, 3, 7, 6, 1, 4, 3, 3, 2, 4, 5, 3, 4, 3, 2, 2, 1, 6, 3, 3, 6, 3, 6, 3, 6, 2, 0, 1, 4, 5]

# %% [markdown]
# # Conclusiones de la Práctica: Simulación de la Demanda Diaria de Productos Tecnológicos
#
# - **Aplicación del Método de la Transformada Inversa:**
#   Se ha demostrado que el método de la transformada inversa es una herramienta eficaz para generar variables aleatorias que siguen una distribución binomial, permitiendo simular de forma realista el número de clientes que realizan una compra en un día.
#
# - **Uso Adecuado de la Distribución Binomial:**
#   La elección de la distribución binomial es apropiada en este contexto, ya que modela el número de éxitos (compras) en un número fijo de ensayos (visitantes diarios), donde cada visita tiene una probabilidad constante de culminar en una compra. Con un promedio de 10 visitantes y una tasa de conversión del 30%, se espera obtener alrededor de 3 compras por día, lo cual es coherente con los resultados simulados.
#
# - **Interpretación de los Resultados:**
#   La variabilidad observada en las simulaciones refleja la naturaleza aleatoria de las compras diarias. La distribución de frecuencias obtenida mediante histogramas permite identificar el comportamiento típico y las posibles desviaciones del promedio esperado, lo que es crucial para la toma de decisiones en la gestión de inventarios y estrategias de marketing.
#
# - **Herramienta para la Toma de Decisiones:**
#   La simulación de la demanda diaria permite a los gestores de la tienda en línea prever escenarios y ajustar niveles de stock para minimizar tanto el exceso de inventario como la pérdida de ventas, optimizando así la eficiencia operativa y la satisfacción del cliente.
#
# - **Validación y Facilidad de Implementación:**
#   La implementación en Python, utilizando bibliotecas como NumPy y Matplotlib, facilita la generación y visualización de los datos simulados, ofreciendo una forma práctica y replicable de evaluar y ajustar el modelo de demanda según los parámetros del negocio.
